# %%
import pandas as pd
import yfinance as yf
from summarytools import dfSummary
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', 'BTC-USD', 'ETH-USD', 'SOL-USD', 'XRP-USD']

# %%
df = yf.download(tickers, period="1mo", interval='1d')['Close']
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
df.columns
# Out:
# Index(['BTC-USD', 'ETH-USD', 'SOL-USD', 'XRP-USD', '^GSPC'], dtype='object', name='Ticker')

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Ticker
# BTC-USD    0
# ETH-USD    0
# SOL-USD    0
# XRP-USD    0
# ^GSPC      0
# dtype: int64

# %%
df
# Out:
# Ticker                          BTC-USD      ETH-USD     SOL-USD   XRP-USD  \
# Date
# 2024-07-31 00:00:00+00:00  64619.250000  3231.295654  171.826157  0.623939
# 2024-08-01 00:00:00+00:00  65357.500000  3201.564453  167.672119  0.596464
# 2024-08-02 00:00:00+00:00  61415.066406  2986.013184  152.638229  0.560771
# 2024-08-05 00:00:00+00:00  53991.457031  2417.206299  129.864304  0.489466
# 2024-08-06 00:00:00+00:00  56034.316406  2458.723877  144.090363  0.505697
# 2024-08-07 00:00:00+00:00  55027.460938  2336.589355  144.632095  0.600810
# 2024-08-08 00:00:00+00:00  61710.136719  2683.352783  162.930740  0.617577
# 2024-08-09 00:00:00+00:00  60880.113281  2599.598633  156.457214  0.581153
# 2024-08-12 00:00:00+00:00  59354.515625  2724.431885  146.454239  0.568768
# 2024-08-13 00:00:00+00:00  60609.566406  2703.671875  146.712692  0.576399
# 2024-08-14 00:00:00+00:00  58737.269531  2662.914795  143.923462  0.569192
# ...

# %%
# %%capture
# !uv pip install summarytools

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_e1ab8 thead>tr>th {
#   text-align: left;
# }
# #T_e1ab8_row0_col0, #T_e1ab8_row1_col0, #T_e1ab8_row2_col0, #T_e1ab8_row3_col0, #T_e1ab8_row4_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_e1ab8_row0_col1, #T_e1ab8_row1_col1, #T_e1ab8_row2_col1, #T_e1ab8_row3_col1, #T_e1ab8_row4_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_e1ab8_row0_col2, #T_e1ab8_row1_col2, #T_e1ab8_row2_col2, #T_e1ab8_row3_col2, #T_e1ab8_row4_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_e1ab8_row0_col3, #T_e1ab8_row1_col3, #T_e1ab8_row2_col3, #T_e1ab8_row3_col3, #T_e1ab8_row4_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
# ...

# %%
for ticker in tickers:
    plt.figure()  # Создание нового рисунка
    df[ticker].plot(title=ticker)  # Построение графика для каждого тикера
    plt.show()  # Отображение графика

# %%
import matplotlib.pyplot as plt
